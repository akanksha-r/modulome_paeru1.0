# %%
from pymodulon.core import *
from pymodulon.plotting import *
from pymodulon.enrichment import *
from pymodulon.compare import *
from pymodulon.io import *
from os import path

# %%
# Enter the location of your data here
data_dir = path.join("..","data","processed_data")

ica_data = IcaData(M = path.join(data_dir,'M.csv'),
                   A = path.join(data_dir,'A.csv'),
                   X = path.join(data_dir,'X.csv'),
                   gene_table = path.join(data_dir,'gene_info.csv'),
                   sample_table = path.join(data_dir,'metadata_qc.csv'),
                   trn = path.join(data_dir,'TRN.csv'),
                   imodulon_table = path.join(data_dir,'iModulone_table.csv'))

# %%
ica_data.imodulon_table
# Out:
#           iModulon_name  regulator    pvalue        qvalue  recall  precision  \
# 0                NarL-1   NarL/Dnr  5.22E-16  8.760000e-12    0.28   0.777778
# 1                  DhcR       DhcR  6.94E-10  1.160000e-05    1.00   0.500000
# 2     Uncharacterized-1        NaN       NaN           NaN     NaN        NaN
# 3                  EatR       EatR  1.25E-13  1.050000e-09    1.00   0.800000
# 4                  AtuR  AtuR/LaoR  4.47E-26  7.500000e-22    1.00   0.476190
# ..                  ...        ...       ...           ...     ...        ...
# 99   Uncharacterized-15        NaN       NaN           NaN     NaN        NaN
# 100  Uncharacterized-16        NaN       NaN           NaN     NaN        NaN
# 101     Translational-3        NaN       NaN           NaN     NaN        NaN
# 102                AcoR       AcoR         0  0.000000e+00    1.00   1.000000
# 103  Uncharacterized-17        NaN       NaN           NaN     NaN        NaN
#
#       f1score    TP  regulon_size  imodulon_size  n_regs  Exp_variance  \
# 0    0.411765   7.0          25.0            9.0     2.0         0.330
# 1    0.666667   3.0           3.0            6.0     1.0         0.260
# 2         NaN   NaN           NaN            NaN     NaN         0.750
# 3    0.888889   4.0           4.0            5.0     1.0         0.190
# 4    0.645161  10.0          10.0           21.0     2.0         0.250
# ..        ...   ...           ...            ...     ...           ...
# 99        NaN   NaN           NaN            NaN     NaN         0.260
# 100       NaN   NaN           NaN            NaN     NaN         0.054
# 101       NaN   NaN           NaN            NaN     NaN         2.630
# 102  1.000000   6.0           6.0            6.0     1.0         0.200
# 103       NaN   NaN           NaN            NaN     NaN         0.600
#
#                         General function  \
# 0                    Nitrogen metabolism
# 1    Amino acid transport and metabolism
# 2                                    NaN
# 3    Amino acid transport and metabolism
# 4                      Carbon Metabolism
# ..                                   ...
# 99                                   NaN
# 100                                  NaN
# 101                                  NaN
# 102                    Carbon Metabolism
# 103                                  NaN
#
#                                   Function  \
# 0                Denitrification (Nitrate)
# 1                     Carnitine catabolism
# 2                                      NaN
# 3                 Ethanolamine utilization
# 4                     Geraniol degradation
# ..                                     ...
# 99                                     NaN
# 100                                    NaN
# 101                                    NaN
# 102  2,3-butanediol and acetoin catabolism
# 103                                    NaN
#
#                                    Category            Operon  \
# 0                         Energy Metabolism         narIJHGK2
# 1    Amino Acid and Nucleotide Biosynthesis           atoDABE
# 2                           Uncharacterized               NaN
# 3    Amino Acid and Nucleotide Biosynthesis  PA4022-eat-eutBC
# 4                 Carbon Source Utilization        atuABCDEFG
# ..                                      ...               ...
# 99                          Uncharacterized               NaN
# 100                         Uncharacterized               NaN
# 101                           Translational               NaN
# 102               Carbon Source Utilization           acoXABC
# 103                         Uncharacterized               NaN
#
#     Upregulating conditions      Downregulating conditions
# 0              LB | Biofilm  p-anisaldehyde | NaNO2 | EDTA
# 1                   Biofilm             M9_AA|PAO1_RsmS149
# 2       Planktonic_Clin_Rif                    M9glucAA_Zn
# 3           delHfq | delCrc     LB | M9glucAA_Cu|wspF|yhjH
# 4                  Farnesol           M9glucAA_Zn, delgluc
# ..                      ...                            ...
# 99                      NaN                            NaN
# 100                     NaN                            NaN
# 101                     NaN                            NaN
# 102                     NaN                            NaN
# 103                     NaN                            NaN
#
# [104 rows x 18 columns]

# %%
# save_to_json(ica_data,path.join("..","paeru_104_imodulon_ica.json"))
