# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.patches as mpatches
from os import path

from pymodulon.core import IcaData
from pymodulon.plotting import *
from pymodulon.io import load_json_model

# %%
ica_data = load_json_model('../paeru_104_imodulon_ica.json')

# %%
groups ={
        'Paeru_0039': 'Paeru_PRECISE (PAO1 strain)',  'Paeru_0052': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0053': 'Paeru_PRECISE (PAO1 strain)',  'Paeru_0070': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0071': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0072': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0073': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0074': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0075': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0077': 'Paeru_PRECISE (PAO1 strain)',  'Paeru_0137': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0138': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0161': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0162': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0260': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0261': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0262': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0263': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0264': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0265': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0266': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0267': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0268': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0269': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0270': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0271': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0282': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0283': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0284': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0285': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0286': 'Paeru_PRECISE (PAO1 strain)', 'Paeru_0287': 'Paeru_PRECISE (PAO1 strain)',
        'Paeru_0017':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0018':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0019':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0020':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0037':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0038':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0042':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0043':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0044':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0045':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0046':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0047':'Paeru_PRECISE (PAO1 (delmexB) strain)',  'Paeru_0058':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0059':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0060':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0063':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0064':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0065':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0066':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0068':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0069':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0106':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0107':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0111':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0112':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0131':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0132':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0166':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0167':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0220':'Paeru_PRECISE (PAO1 (delmexB) strain)', 'Paeru_0221':'Paeru_PRECISE (PAO1 (delmexB) strain)',        
        'Paeru_0033':'Oxidative stress', 'Paeru_0034':'Oxidative stress', 'Paeru_0035':'Oxidative stress', 'Paeru_0036':'Oxidative stress','Paeru_0133': 'Oxidative stress', 'Paeru_0134': 'Oxidative stress', 'Paeru_0135': 'Oxidative stress', 'Paeru_0136': 'Oxidative stress',
        'Paeru_0048':'low pH','Paeru_0049':'low pH',
        'Paeru_0050':'Iron starvation','Paeru_0051':'Iron starvation',
        'Paeru_0039':'Osmotic stress','Paeru_0040':'Osmotic stress','Paeru_0056': 'Osmotic stress', 'Paeru_0057': 'Osmotic stress', 'Paeru_0061':'Osmotic stress', 'Paeru_0062':'Osmotic stress', 'Paeru_0258': 'Osmotic stress', 'Paeru_0259': 'Osmotic stress',
        'ERX3593017':'Hypoxia','ERX3593018':'Hypoxia'
        }

# %%
compare_activities(ica_data,'RpoS-2','Translational-1',groups=groups,colors=['mistyrose','firebrick','steelblue','black','green','orange','peru','gray'])
# Out:
# <AxesSubplot:xlabel='RpoS-2 iModulon Activity', ylabel='Translational-1 iModulon Activity'>
