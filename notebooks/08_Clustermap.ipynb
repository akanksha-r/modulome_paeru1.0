# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.patches as mpatches
from os import path

from pymodulon.core import IcaData
from pymodulon.plotting import *
from pymodulon.io import load_json_model

# %% [markdown]
# ## Clusering all Paeru iModulons

# %%
ica_data = load_json_model('../paeru_104_imodulon_ica.json')
cluster_activities(ica_data, show_best_clusters=True, n_best_clusters=2, correlation_method='pearson')
# Out:
# [AgglomerativeClustering(affinity='precomputed', compute_full_tree=True,
#                          distance_threshold=0.7000000000000001,
#                          linkage='complete', n_clusters=None)]
