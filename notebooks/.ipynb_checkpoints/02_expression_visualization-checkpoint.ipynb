# %% [markdown]
# # <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-data" data-toc-modified-id="Load-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load data</a></span></li><li><span><a href="#Data-Growth" data-toc-modified-id="Data-Growth-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Growth</a></span></li><li><span><a href="#Hierarchical-Clustering" data-toc-modified-id="Hierarchical-Clustering-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Hierarchical Clustering</a></span></li><li><span><a href="#PCA" data-toc-modified-id="PCA-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>PCA</a></span></li><li><span><a href="#Normalize-to-reference-conditions" data-toc-modified-id="Normalize-to-reference-conditions-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Normalize to reference conditions</a></span></li></ul></div>

# %% [markdown]
# <font size="4">This is a template notebook for exploratory analysis on your organism's QC'ed dataset.</font>

# %%
import pandas as pd
import os
from os import path
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sns.set_style('ticks')

# %% [markdown]
# # Load data

# %%
#organism = "Pseudomonas_aeruginosa"

# %%
#org_dir = path.join('../data/organisms/',organism)
org_dir = path.join('../../modulome_paeru/data/new_run_04_14_2021/part02/')
os.listdir(org_dir)
# Out:
# ['metadata_ids.txt',
#  'metadata_overall_final.csv',
#  '.DS_Store',
#  'logTPM_overall.csv']

# %%
DF_metadata = pd.read_csv(os.path.join(org_dir,'metadata_overall_final.csv'),index_col=0)
DF_log_tpm = pd.read_csv(os.path.join(org_dir,'logTPM_overall.csv'),index_col=0)

# DF_metadata = pd.read_csv(os.path.join(org_dir,'metadata_OVERALL_qc1.csv'),index_col=0)
# DF_log_tpm = pd.read_csv(os.path.join(org_dir,'log_tpm_OVERALL_qc1.csv'),index_col=0)

# %% [markdown]
# # Data Growth

# %%
DF_metadata['ReleaseDate'] = pd.to_datetime(DF_metadata['ReleaseDate'])

# %%
local = DF_metadata.loc[[x for x in DF_metadata.index if x.startswith('Paeru')]]

# %%
first_date = min(DF_metadata['ReleaseDate'])
last_date = max(DF_metadata['ReleaseDate'])
date_range = pd.date_range(start=first_date,end=last_date,freq='YS')

# %%
fig,ax = plt.subplots(figsize=(5,5))
growth = DF_metadata['ReleaseDate'].value_counts().sort_index().cumsum()
growth2 = local['ReleaseDate'].value_counts().sort_index().cumsum()
growth2.loc[pd.Timestamp('2013-02-01 00:00:00')] = 0
growth2.loc[pd.Timestamp('2020-03-01 00:00:00')] = growth2.max()
growth.plot(ax=ax,label='All samples')
growth2.plot(ax=ax,label='PRECISE samples')
plt.xticks(date_range,date_range.strftime('%Y'),rotation=0,ha='center')
ax.tick_params(labelsize=12)
ax.set_xlabel('Year',fontsize=14)
ax.set_ylabel('Number of Samples',fontsize=14)
plt.legend(fontsize=12)

#plt.savefig("../../../UCSD/Pseudo_Precise/Figures/plots/Pseudo_Precise_literature.pdf", transparent=True, bbox_inches = 'tight')

# %% [markdown]
# # Hierarchical Clustering

# %% [markdown]
# <font size=4> A clustermap is a great way to visualize the global correlations between one sample and all others. The following code uses hierarchical clustering to identify specific clusters in the clustermap <font size=4>
#
# <font size=4> To increase the number of clusters, decrease the value of `thresh`. To decrease the number of clusters, increase the value of `thresh` <font size=4>

# %%
import scipy.cluster.hierarchy as sch
import matplotlib.patches as patches
# change this to get different number of clusters
thresh = .3

# retrieve clusters using fcluster 
corr = DF_log_tpm.corr()
corr.fillna(0,inplace=True)
dist = sch.distance.pdist(corr)
link = sch.linkage(dist, method='complete')
clst = pd.DataFrame(index=DF_log_tpm.columns)
clst['cluster'] = sch.fcluster(link, thresh * dist.max(), 'distance')

#get colors for each cluster
cm = plt.cm.get_cmap('tab20')
clr = dict(zip(clst.cluster.unique(), cm.colors))
clst['color'] = clst.cluster.map(clr)

print('Number of cluster: ', len(clr))
# Out:
# Number of cluster:  4

# %% [markdown]
# <font size="4">To view sample IDs in the clustermap, set `xticklabels` and `yticklabels` to `True`. You can increase the `size` variable to improve readability of sample IDs<font>

# %%
size = 9

legend_TN = [patches.Patch(color=c, label=l) for l,c in clr.items()]

sns.set(rc={'figure.facecolor':'white'})
g = sns.clustermap(DF_log_tpm.corr(), figsize=(size,size), 
                   row_linkage=link, col_linkage=link, col_colors=clst.color,
                  yticklabels=False, xticklabels=False)

l2=g.ax_heatmap.legend(loc='upper left', bbox_to_anchor=(1.01,0.85), handles=legend_TN,frameon=True)
l2.set_title(title='Clusters',prop={'size':10})

plt.savefig("../../../UCSD/Pseudo_Precise/Figures/paeru_precise02/PSeudo_Precise_b4_after_QC_QA.pdf", transparent=True, bbox_inches = 'tight')

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA
import numpy as np

# %% [markdown]
# <font size="4"> First compute principal components.</font>

# %%
pca = PCA()
DF_weights = pd.DataFrame(pca.fit_transform(DF_log_tpm.T),index=DF_log_tpm.columns)
DF_components = pd.DataFrame(pca.components_.T,index=DF_log_tpm.index)

# %% [markdown]
# <font size="4"> Next, plot the cumulative explained variance</font>

# %%
# Set the explained variance threshold
var_cutoff = 0.99

fig,ax = plt.subplots(figsize=(5,3.5))
pca_var = np.cumsum(pca.explained_variance_ratio_)
ax.plot(pca_var)
dims = np.where(pca_var > var_cutoff)[0][0] + 1
ax.vlines(dims,0,1,linestyles='dotted')
ax.hlines(var_cutoff,0,len(DF_log_tpm.columns),linestyles='dotted')
ax.set_ylim(0,1)
ax.set_xlim(0,len(DF_log_tpm.columns))
ax.set_ylabel('Fraction of Explained Variance',fontsize=12)
ax.set_xlabel('Number of Dimensions',fontsize=12)
ax.set_title('Cumulative Explained Variance',fontsize=16)
print('Number of dimensions for 99% of variance:',dims)

plt.savefig("../../../UCSD/Pseudo_Precise/Figures/paeru_precise02/PSeudo_Precise_ccumulative_variance.pdf", transparent=True, bbox_inches = 'tight')
# Out:
# Number of dimensions for 99% of variance: 207

# %% [markdown]
# <font size="4">Finally, plot the first two principle components. The following code colors data by Project Name.</font>

# %%
fig,ax = plt.subplots(figsize=(7,5))
for name,group in DF_metadata.groupby('project'):
    idx = DF_log_tpm.loc[:,group.index.tolist()].columns.tolist()
    ax.scatter(DF_weights.loc[idx,0],
               DF_weights.loc[idx,1],
               label=name,alpha=0.8)
ax.set_xlabel('Component 1: %.1f%%'%(pca.explained_variance_ratio_[0]*100),fontsize=14)
ax.set_ylabel('Component 2: %.1f%%'%(pca.explained_variance_ratio_[1]*100),fontsize=14)
ax.set_title('Principal Component Plot',fontsize=18)
plt.legend(bbox_to_anchor=(1,1),fontsize=12,ncol=2)

plt.savefig("../../../UCSD/Pseudo_Precise/Figures/paeru_precise02/PSeudo_Precise_PCA_samples.pdf", transparent=True, bbox_inches = 'tight')

# %% [markdown]
# # Normalize to reference conditions

# %%
project_exprs = []
for name,group in DF_metadata.groupby('project'):
    ref_cond = group.refrence.unique()
    
    # Ensure that there is only one reference condition per project
    assert(len(ref_cond) == 1)
    ref_cond = ref_cond[0]
    
    # Ensure the reference condition is in fact in the project
    assert(ref_cond in group.condition.tolist())
    
    # Get reference condition sample ids
    ref_samples = group[group.condition == ref_cond].index
    
    # Get reference condition expression
    ref_expr = DF_log_tpm[ref_samples].mean(axis=1)
    
    # Subtract reference expression from project
    project_exprs.append(DF_log_tpm[group.index].sub(ref_expr,axis=0))

DF_log_tpm_norm = pd.concat(project_exprs,axis=1)

# %%
DF_log_tpm_norm.head()
# Out:
#    SRX7442752  SRX7442753  SRX7442754  SRX7442755  SRX7442756  SRX7442757  \
# 0   -0.059838    0.059838   -0.223628   -0.064501    0.272055    0.250233
# 1   -0.129988    0.129988   -0.775982   -0.558346    0.113325    0.225710
# 2   -0.059231    0.059231   -0.029049    0.134841   -0.247534   -0.236541
# 3   -0.106282    0.106282   -0.020711    0.004618   -0.158098   -0.123305
# 4    0.130988   -0.130988   -0.090968   -0.174002   -0.172446    0.083005
#
#    SRX7442758  SRX7442759  SRX7442761  SRX7874204  ...  ERX2813654  \
# 0    0.132425   -0.012312    0.207182   -0.039016  ...   -0.043868
# 1   -0.015325   -0.625404   -0.506919   -0.022261  ...    0.089232
# 2   -0.262634    0.157336    0.162652   -0.027968  ...    0.170602
# 3   -0.211630   -0.005664    0.179065   -0.010633  ...    0.117932
# 4   -0.118166   -0.095737   -0.040259    0.012668  ...    0.020867
#
#    ERX2813656  ERX2813657  ERX2813658  SRX2711962  SRX2711963  SRX2711964  \
# 0    0.141774    0.113458    0.192018    0.059067   -0.059067    1.018696
# 1   -0.003227   -0.132619   -0.033129    0.055782   -0.055782    0.562237
# 2    0.247142   -0.138158    0.387217    0.085623   -0.085623    0.466539
# 3    0.440415    0.357232    0.577156    0.101930   -0.101930    0.558789
# 4    0.411756    0.303261    0.528423    0.016315   -0.016315   -0.017226
#
#    SRX2711965  SRX2711966  SRX2711967
# 0    1.145877   -0.002653   -0.574276
# 1    0.462859   -0.023202   -0.611902
# 2    0.470517   -0.321009   -0.732021
# 3    0.522018    0.665112   -0.079156
# 4    0.095311   -1.197808   -1.674614
#
# [5 rows x 411 columns]

# %% [markdown]
# <font size=4>Uncomment this code to save the log_tpm_norm file</font>

# %%
 DF_log_tpm_norm.to_csv(path.join(org_dir,'log_tpm_norm_overall_final.csv'))

# %%
fig,ax = plt.subplots(figsize=(2,3))
plt.bar(range(5),[-2,-3,-2.6,-20,-19],width=1,linewidth=0,color=['tab:orange']*3+['tab:blue']*2)
plt.xticks([1,3.5],labels=('Ctrl','Izd'),fontsize=16)
plt.yticks([])
plt.ylabel('sigD Activity',fontsize=16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5ba31e440fd5> in <module>
# ----> 1 fig,ax = plt.subplots(figsize=(2,3))
#       2 plt.bar(range(5),[-2,-3,-2.6,-20,-19],width=1,linewidth=0,color=['tab:orange']*3+['tab:blue']*2)
#       3 plt.xticks([1,3.5],labels=('Ctrl','Izd'),fontsize=16)
#       4 plt.yticks([])
#       5 plt.ylabel('sigD Activity',fontsize=16)
#
# NameError: name 'plt' is not defined

# %%
DF_metadata = pd.read_csv('../../modulome_paeru/data/new_run_04_14_2021/metadata_literature_Paer_PRECISE_qc.csv', sep='\t', index_col=0)

# %%
DF_metadata['ReleaseDate'] = pd.to_datetime(DF_metadata['ReleaseDate'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/pymodulon/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ReleaseDate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-99ac862f5ff2> in <module>
# ----> 1 DF_metadata['ReleaseDate'] = pd.to_datetime(DF_metadata['ReleaseDate'])
#
# ~/opt/anaconda3/envs/pymodulon/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/pymodulon/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
# -> 2893                 raise KeyError(key) from err
#    2894
#    2895         if tolerance is not None:
#
# KeyError: 'ReleaseDate'

# %%
local = pd.read_csv('../../modulome_paeru/data/metadata_qc.csv',index_col=0)
local['ReleaseDate'] = pd.to_datetime(local['ReleaseDate'])

# %%
#local['ReleaseDate']
local [local['ReleaseDate'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ReleaseDate, TaxID, ScientificName, species_tax_id, class_tax_id, strain_tax_id, species, LibraryLayout, Platform, Model, Run, SRAStudy, BioProject, ProjectID, Sample, BioSample, Submission, LibraryStrategy, LibrarySelection, LibrarySource, Body_Site, CenterName, InsertSize, InsertDev, SRA ID, GEO Series, GEO Sample, PMID, Biosample ID, biosample_strain, strain_final, biosample_genotype, project, condition, reference_condition, condition_name_old, project_name_old, replicates, refrence_condition_old, strain_description, base_media, carbon_source, nitrogen_source, aerobicity, supplement, temperature, pH, growth_phase, OD, additional_notes, passed_fastqc, passed_reads_mapped_to_CDS, passed_global_correlation, full_name, passed_similar_replicates, passed_number_replicates]
# Index: []
#
# [0 rows x 56 columns]

# %%
DF_metadata = pd.concat([DF_metadata,local])

# %%
first_date = min(DF_metadata['ReleaseDate'])
last_date = max(DF_metadata['ReleaseDate'])
date_range = pd.date_range(start=first_date,end=last_date,freq='YS')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-c0233185268f> in <module>
#       1 first_date = min(DF_metadata['ReleaseDate'])
#       2 last_date = max(DF_metadata['ReleaseDate'])
# ----> 3 date_range = pd.date_range(start=first_date,end=last_date,freq='YS')
#
# ~/opt/anaconda3/envs/pymodulon/lib/python3.8/site-packages/pandas/core/indexes/datetimes.py in date_range(start, end, periods, freq, tz, normalize, name, closed, **kwargs)
#     997         freq = "D"
#     998
# --> 999     dtarr = DatetimeArray._generate_range(
#    1000         start=start,
#    1001         end=end,
#
# ~/opt/anaconda3/envs/pymodulon/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in _generate_range(cls, start, end, periods, freq, tz, normalize, ambiguous, nonexistent, closed)
#     374
#     375         if start is NaT or end is NaT:
# --> 376             raise ValueError("Neither `start` nor `end` can be NaT")
#     377
#     378         left_closed, right_closed = dtl.validate_endpoints(closed)
#
# ValueError: Neither `start` nor `end` can be NaT

# %%
fig,ax = plt.subplots(figsize=(5,5))
growth = DF_metadata['ReleaseDate'].value_counts().sort_index().cumsum()
growth2 = local['ReleaseDate'].value_counts().sort_index().cumsum()
#growth2.loc[pd.Timestamp('2016-05-01 00:00:00')] = 0
#growth2.loc[pd.Timestamp('2020-03-01 00:00:00')] = growth2.max()
growth.plot(ax=ax,label='All samples')
growth2.plot(ax=ax,label='PRECISE samples')
plt.xticks(date_range,date_range.strftime('%Y'),rotation=0,ha='center')
ax.tick_params(labelsize=12)
ax.set_xlabel('Year',fontsize=14)
ax.set_ylabel('Number of Samples',fontsize=14)
plt.legend(fontsize=12)

plt.savefig("../../../UCSD/Pseudo_Precise/Figures/plots/PSeudo_Precise_literature_after_QC_try1.pdf", transparent=True, bbox_inches = 'tight')

# %%
growth2
# Out:
# 2014-02-01 00:00:00      4
# 2014-06-15 12:59:00     14
# 2014-06-20 07:29:00     15
# 2014-06-21 00:00:00     22
# 2014-09-07 01:24:00     42
#                       ...
# 2020-04-22 16:10:00    440
# 2020-04-28 17:02:00    450
# 2020-06-06 21:20:00    452
# 2020-07-01 16:45:00    465
# 2020-08-13 16:24:00    470
# Name: ReleaseDate, Length: 93, dtype: int64

# %%
len(local)
# Out:
# 470

# %%
DF_metadata['ReleaseDate'] = pd.to_datetime(DF_metadata['ReleaseDate'])

# %%
local = pd.read_csv('../../modulome_paeru/data/metadata_qc_sample.csv.csv',index_col=0)
local['ReleaseDate'] = pd.to_datetime(local['harvest-date'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-53-33d6354f2869> in <module>
# ----> 1 local = pd.read_csv('../../modulome_paeru/data/metadata_qc_sample.csv.csv',index_col=0)
#       2 local['ReleaseDate'] = pd.to_datetime(local['harvest-date'])
#
# ~/opt/anaconda3/envs/pymodulon/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/opt/anaconda3/envs/pymodulon/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/opt/anaconda3/envs/pymodulon/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# ~/opt/anaconda3/envs/pymodulon/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# ~/opt/anaconda3/envs/pymodulon/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1996         kwds["usecols"] = self.usecols
#    1997
# -> 1998         self._reader = parsers.TextReader(src, **kwds)
#    1999         self.unnamed_cols = self._reader.unnamed_cols
#    2000
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../modulome_paeru/data/metadata_qc_sample.csv.csv'

# %%
DF_metadata = pd.concat([DF_metadata,local])

# %%
first_date = min(DF_metadata['ReleaseDate'])
last_date = max(DF_metadata['ReleaseDate'])
date_range = pd.date_range(start=first_date,end=last_date,freq='YS')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-c0233185268f> in <module>
# ----> 1 first_date = min(DF_metadata['ReleaseDate'])
#       2 last_date = max(DF_metadata['ReleaseDate'])
#       3 date_range = pd.date_range(start=first_date,end=last_date,freq='YS')
#
# TypeError: '<' not supported between instances of 'str' and 'Timestamp'

# %%
fig,ax = plt.subplots(figsize=(5,5))
growth = DF_metadata['ReleaseDate'].value_counts().sort_index().cumsum()
growth2 = local['ReleaseDate'].value_counts().sort_index().cumsum()
growth2.loc[pd.Timestamp('2014-06-01 00:00:00')] = 0
growth2.loc[pd.Timestamp('2020-03-01 00:00:00')] = growth2.max()
growth.plot(ax=ax,label='All samples')
growth2.plot(ax=ax,label='PRECISE samples')
plt.xticks(date_range,date_range.strftime('%Y'),rotation=0,ha='center')
ax.tick_params(labelsize=12)
ax.set_xlabel('Year',fontsize=14)
ax.set_ylabel('Number of Samples',fontsize=14)
plt.legend(fontsize=12)

plt.savefig("../../../UCSD/Pseudo_Precise/Figures/plots/PSeudo_Precise_literature_after_QC_1.pdf", transparent=True, bbox_inches = 'tight')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-ba63c4cd204b> in <module>
#       1 fig,ax = plt.subplots(figsize=(5,5))
# ----> 2 growth = DF_metadata['ReleaseDate'].value_counts().sort_index().cumsum()
#       3 growth2 = local['ReleaseDate'].value_counts().sort_index().cumsum()
#       4 growth2.loc[pd.Timestamp('2014-06-01 00:00:00')] = 0
#       5 growth2.loc[pd.Timestamp('2020-03-01 00:00:00')] = growth2.max()
#
# ~/opt/anaconda3/envs/pymodulon/lib/python3.8/site-packages/pandas/core/series.py in sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    3477                     return self.copy()
#    3478
# -> 3479             indexer = nargsort(
#    3480                 index, kind=kind, ascending=ascending, na_position=na_position
#    3481             )
#
# ~/opt/anaconda3/envs/pymodulon/lib/python3.8/site-packages/pandas/core/sorting.py in nargsort(items, kind, ascending, na_position, key)
#     306         non_nans = non_nans[::-1]
#     307         non_nan_idx = non_nan_idx[::-1]
# --> 308     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     309     if not ascending:
#     310         indexer = indexer[::-1]
#
# TypeError: '<' not supported between instances of 'str' and 'Timestamp'
